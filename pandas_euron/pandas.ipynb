# %% [markdown]
# ### import pandas as pd

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 709         0       3               Rice, Mrs. William (Margaret Norton)
# 710         0       2                              Montvila, Rev. Juozas
# 711         1       1                       Graham, Miss. Margaret Edith
# 712         1       1                              Behr, Mr. Karl Howell
# 713         0       3                                Dooley, Mr. Patrick
#
#         sex   age     fare  sibsp  parch
# 0      male  22.0   7.2500      1      0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age     fare  sibsp  parch
# 0    male  22.0   7.2500      1      0
# 1  female  38.0  71.2833      1      0
# 2  female  26.0   7.9250      0      0
# 3  female  35.0  53.1000      1      0
# 4    male  35.0   8.0500      0      0

# %%
df.tail()
# Out:
#      survived  pclass                                  name     sex   age  \
# 709         0       3  Rice, Mrs. William (Margaret Norton)  female  39.0
# 710         0       2                 Montvila, Rev. Juozas    male  27.0
# 711         1       1          Graham, Miss. Margaret Edith  female  19.0
# 712         1       1                 Behr, Mr. Karl Howell    male  26.0
# 713         0       3                   Dooley, Mr. Patrick    male  32.0
#
#        fare  sibsp  parch
# 709  29.125      0      5
# 710  13.000      0      0
# 711  30.000      0      0
# 712  30.000      0      0
# 713   7.750      0      0

# %%
df.shape
# Out:
# (714, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  714 non-null    int64
#  1   pclass    714 non-null    int64
#  2   name      714 non-null    object
#  3   sex       714 non-null    object
#  4   age       714 non-null    float64
#  5   fare      714 non-null    float64
#  6   sibsp     714 non-null    int64
#  7   parch     714 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 44.8+ KB

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'fare', 'sibsp', 'parch'], dtype='object')

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 709         0       3               Rice, Mrs. William (Margaret Norton)
# 710         0       2                              Montvila, Rev. Juozas
# 711         1       1                       Graham, Miss. Margaret Edith
# 712         1       1                              Behr, Mr. Karl Howell
# 713         0       3                                Dooley, Mr. Patrick
#
#         sex   age     fare  sibsp  parch
# 0      male  22.0   7.2500      1      0
# ...

# %%
df[['pclass', 'fare']]
# Out:
#      pclass     fare
# 0         3   7.2500
# 1         1  71.2833
# 2         3   7.9250
# 3         1  53.1000
# 4         3   8.0500
# ..      ...      ...
# 709       3  29.1250
# 710       2  13.0000
# 711       1  30.0000
# 712       1  30.0000
# 713       3   7.7500
#
# [714 rows x 2 columns]

# %%
df['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 709    3
# 710    2
# 711    1
# 712    1
# 713    3
# Name: pclass, Length: 714, dtype: int64

# %%
type(df['pclass'])
# Out:
# pandas.core.series.Series

# %%
#pandas have two data type one is series and one is dataframe

# %%
type(df[['pclass']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'fare', 'sibsp', 'parch'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df[['name','sex','age']]
# Out:
#                                                   name     sex   age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 709               Rice, Mrs. William (Margaret Norton)  female  39.0
# 710                              Montvila, Rev. Juozas    male  27.0
# 711                       Graham, Miss. Margaret Edith  female  19.0
# 712                              Behr, Mr. Karl Howell    male  26.0
# 713                                Dooley, Mr. Patrick    male  32.0
#
# [714 rows x 3 columns]

# %%
df[['name','sex','age']].head(10)
# Out:
#                                                 name     sex   age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                            McCarthy, Mr. Timothy J    male  54.0
# 6                     Palsson, Master. Gosta Leonard    male   2.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 9                    Sandstrom, Miss. Marguerite Rut  female   4.0

# %%
# https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1 = pd.read_excel("sample_data.xlsx", sheet_name = "sudh2")
df1
# Out:
#     ID       Name  Age   City  Salary
# 0    1   Person_1   21  CityA   30750
# 1    2   Person_2   22  CityB   31500
# 2    3   Person_3   23  CityC   32250
# 3    4   Person_4   24  CityD   33000
# 4    5   Person_5   25  CityA   33750
# 5    6   Person_6   26  CityB   34500
# 6    7   Person_7   27  CityC   35250
# 7    8   Person_8   28  CityD   36000
# 8    9   Person_9   29  CityA   36750
# 9   10  Person_10   20  CityB   37500
# 10   1   Person_1   21  CityA   30750
# 11   2   Person_2   22  CityB   31500
# 12   3   Person_3   23  CityC   32250
# 13   4   Person_4   24  CityD   33000
# 14   5   Person_5   25  CityA   33750
# 15   6   Person_6   26  CityB   34500
# 16   7   Person_7   27  CityC   35250
# 17   8   Person_8   28  CityD   36000
# 18   9   Person_9   29  CityA   36750
# 19  10  Person_10   20  CityB   37500

# %%
df1.shape
# Out:
# (20, 5)

# %%
df1.head(0)
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, City, Salary]
# Index: []

# %%
df1[:]
# Out:
#     ID       Name  Age   City  Salary
# 0    1   Person_1   21  CityA   30750
# 1    2   Person_2   22  CityB   31500
# 2    3   Person_3   23  CityC   32250
# 3    4   Person_4   24  CityD   33000
# 4    5   Person_5   25  CityA   33750
# 5    6   Person_6   26  CityB   34500
# 6    7   Person_7   27  CityC   35250
# 7    8   Person_8   28  CityD   36000
# 8    9   Person_9   29  CityA   36750
# 9   10  Person_10   20  CityB   37500
# 10   1   Person_1   21  CityA   30750
# 11   2   Person_2   22  CityB   31500
# 12   3   Person_3   23  CityC   32250
# 13   4   Person_4   24  CityD   33000
# 14   5   Person_5   25  CityA   33750
# 15   6   Person_6   26  CityB   34500
# 16   7   Person_7   27  CityC   35250
# 17   8   Person_8   28  CityD   36000
# 18   9   Person_9   29  CityA   36750
# 19  10  Person_10   20  CityB   37500

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 709         0       3               Rice, Mrs. William (Margaret Norton)
# 710         0       2                              Montvila, Rev. Juozas
# 711         1       1                       Graham, Miss. Margaret Edith
# 712         1       1                              Behr, Mr. Karl Howell
# 713         0       3                                Dooley, Mr. Patrick
#
#         sex   age     fare  sibsp  parch
# 0      male  22.0   7.2500      1      0
# ...

# %%
df['survived'] == 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 709    False
# 710    False
# 711     True
# 712     True
# 713    False
# Name: survived, Length: 714, dtype: bool

# %%
df[df['survived'] == 1]
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 7           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# ..        ...     ...                                                ...
# 700         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 703         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 704         1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 711         1       1                       Graham, Miss. Margaret Edith
# 712         1       1                              Behr, Mr. Karl Howell
#
#         sex   age     fare  sibsp  parch
# 1    female  38.0  71.2833      1      0
# ...

# %%
df[df['age']<=18]
# Out:
#      survived  pclass                                  name     sex   age  \
# 6           0       3        Palsson, Master. Gosta Leonard    male   2.0
# 8           1       2   Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 9           1       3       Sandstrom, Miss. Marguerite Rut  female   4.0
# 13          0       3  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 15          0       3                  Rice, Master. Eugene    male   2.0
# ..        ...     ...                                   ...     ...   ...
# 680         0       3               Boulos, Miss. Nourelain  female   9.0
# 681         1       1             Lines, Miss. Mary Conover  female  16.0
# 683         1       3            Aks, Mrs. Sam (Leah Rosen)  female  18.0
# 694         1       3       Johnson, Master. Harold Theodor    male   4.0
# 700         1       3      Najib, Miss. Adele Kiamie "Jane"  female  15.0
#
#         fare  sibsp  parch
# 6    21.0750      3      1
# ...

# %%
df['age']<=18
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 709    False
# 710    False
# 711    False
# 712    False
# 713    False
# Name: age, Length: 714, dtype: bool

# %%
df[ (df['survived']==1) & (df['age']<=18)]
# Out:
#      survived  pclass                                      name     sex  \
# 8           1       2       Nasser, Mrs. Nicholas (Adele Achem)  female
# 9           1       3           Sandstrom, Miss. Marguerite Rut  female
# 19          1       3               McGowan, Miss. Anna "Annie"  female
# 30          1       3               Nicola-Yarred, Miss. Jamila  female
# 33          1       2  Laroche, Miss. Simonne Marie Anne Andree  female
# ..        ...     ...                                       ...     ...
# 664         1       2           Richards, Master. George Sibley    male
# 681         1       1                 Lines, Miss. Mary Conover  female
# 683         1       3                Aks, Mrs. Sam (Leah Rosen)  female
# 694         1       3           Johnson, Master. Harold Theodor    male
# 700         1       3          Najib, Miss. Adele Kiamie "Jane"  female
#
#        age     fare  sibsp  parch
# 8    14.00  30.0708      1      0
# ...

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 709         0       3               Rice, Mrs. William (Margaret Norton)
# 710         0       2                              Montvila, Rev. Juozas
# 711         1       1                       Graham, Miss. Margaret Edith
# 712         1       1                              Behr, Mr. Karl Howell
# 713         0       3                                Dooley, Mr. Patrick
#
#         sex   age     fare  sibsp  parch
# 0      male  22.0   7.2500      1      0
# ...

# %%
df['new_col_sudh'] = df['age'] *2

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 709         0       3               Rice, Mrs. William (Margaret Norton)
# 710         0       2                              Montvila, Rev. Juozas
# 711         1       1                       Graham, Miss. Margaret Edith
# 712         1       1                              Behr, Mr. Karl Howell
# 713         0       3                                Dooley, Mr. Patrick
#
#         sex   age     fare  sibsp  parch  new_col_sudh
# ...

# %%
df['new_col']=None

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 709         0       3               Rice, Mrs. William (Margaret Norton)
# 710         0       2                              Montvila, Rev. Juozas
# 711         1       1                       Graham, Miss. Margaret Edith
# 712         1       1                              Behr, Mr. Karl Howell
# 713         0       3                                Dooley, Mr. Patrick
#
#         sex   age     fare  sibsp  parch  new_col_sudh new_col
# ...

# %%
df.to_csv('titanic_new1.csv', index=False)

# %%
df.sort_values(by='age', ascending=False)
# Out:
#      survived  pclass                                  name     sex    age  \
# 498         1       1  Barkworth, Mr. Algernon Henry Wilson    male  80.00
# 679         0       3                   Svensson, Mr. Johan    male  74.00
# 393         0       1               Artagaveytia, Mr. Ramon    male  71.00
# 74          0       1             Goldschmidt, Mr. George B    male  71.00
# 91          0       3                  Connors, Mr. Patrick    male  70.50
# ..        ...     ...                                   ...     ...    ...
# 59          1       2         Caldwell, Master. Alden Gates    male   0.83
# 509         1       3                Baclini, Miss. Eugenie  female   0.75
# 374         1       3         Baclini, Miss. Helene Barbara  female   0.75
# 602         1       2             Hamalainen, Master. Viljo    male   0.67
# 640         1       3       Thomas, Master. Assad Alexander    male   0.42
#
#         fare  sibsp  parch  new_col_sudh new_col
# ...

# %%
df['sex'].value_counts()
# Out:
# sex
# male      453
# female    261
# Name: count, dtype: int64

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    424
# 1    290
# Name: count, dtype: int64

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.describe(include='object')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
df.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.describe(include="object")
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df['gender'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df[(df['gender']=='female') & (df['math score']>80) ]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 2    female        group B             master's degree  standard
# 6    female        group B                some college  standard
# 56   female        group E          associate's degree  standard
# 102  female        group D          associate's degree  standard
# 106  female        group D             master's degree  standard
# ..      ...            ...                         ...       ...
# 957  female        group D             master's degree  standard
# 962  female        group E          associate's degree  standard
# 970  female        group D           bachelor's degree  standard
# 979  female        group C          associate's degree  standard
# 995  female        group E             master's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 2                      none          90             95             93
# ...

# %%
(df['gender']=='female') & (df['math score']>80)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df[(df['race/ethnicity']=="group A") | (df['race/ethnicity']=="group B")]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 985    male        group A                 high school      standard
# 988  female        group A            some high school  free/reduced
# 991  female        group B            some high school      standard
# 994    male        group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[(df['race/ethnicity'].isin(['group A','group B']))]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 985    male        group A                 high school      standard
# 988  female        group A            some high school  free/reduced
# 991  female        group B            some high school      standard
# 994    male        group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[(df['math score']>90) & (df['math score']<=100) ]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 171    male        group E            some high school      standard
# 179  female        group D            some high school      standard
# 233    male        group E            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# ...

# %%
df[ 90<(df['math score'])<=100 ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5916\2001168277.py in ?()
# ----> 1 df[ 90<(df['math score'])<=100 ]
#
# c:\Users\Vishal\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['math score'].between(90,100)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool

# %%
df[df['math score'].between(90,100)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 171    male        group E            some high school      standard
# 179  female        group D            some high school      standard
# 233    male        group E            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 299    male        group D          associate's degree  free/reduced
# ...

# %%
#loc and iloc

df.loc[0:5, ['gender', 'math score', 'lunch']]
# Out:
#    gender  math score         lunch
# 0  female          72      standard
# 1  female          69      standard
# 2  female          90      standard
# 3    male          47  free/reduced
# 4    male          76      standard
# 5  female          71      standard

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.iloc[0:5,[7]]
# Out:
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %%
#location is work on actual and name based column name or array

#iloc  is work on range based or we have to provide index position

# %%
df.loc[0:4, ['race/ethnicity', 'lunch']]
# Out:
#   race/ethnicity         lunch
# 0        group B      standard
# 1        group C      standard
# 2        group B      standard
# 3        group A  free/reduced
# 4        group C      standard

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
def math_performance(score):
    if score['math score']>90:
        return 'excellent'
    elif score['math score']>75:
        return 'good'
    else:
        return 'average'
    
df['math_performance'] = df.apply(math_performance, axis=1)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
def newCol(score):
    return score['race/ethnicity'].replace("group", "")

df['newCol1'] = df.apply(newCol, axis=1)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   math_performance newCol newCol1
# 0          average      B       B
# 1          average      C       C
# 2             good      B       B
# ...

# %%
df['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df['gender_num']=df['gender'].map({"female":1, "male":0})

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   math_performance newCol newCol1  gender_num
# 0          average      B       B           1
# 1          average      C       C           1
# ...

# %%
df['race/ethnicity'].map({"group A":"A", "group B":"B", "group C":"C", "group D":"D", "group E":"E"})
# Out:
# 0      B
# 1      C
# 2      B
# 3      A
# 4      C
#       ..
# 995    E
# 996    C
# 997    C
# 998    D
# 999    D
# Name: race/ethnicity, Length: 1000, dtype: object

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 2

# %%
df.sort_values(by='math score', ascending=True)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 458  female        group E           bachelor's degree      standard
# 451  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.groupby('gender')['math score'].mean()
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
pd.pivot_table(df,values='math score', index='gender', columns='lunch', aggfunc='mean')
# Out:
# lunch   free/reduced   standard
# gender
# female     55.814815  68.124620
# male       62.457831  72.022152

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'math_performance', 'newCol', 'newCol1', 'gender_num'],
#       dtype='object')

# %%
df.drop(columns=["newCol1"])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.drop(columns=['newCol1'], inplace=True)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df['math score'].dtype
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   math_performance newCol  gender_num
# 0          average      B           1
# 1          average      C           1
# ...

# %%
df['math score'].astype('float64')
# Out:
# 0      72.0
# 1      69.0
# 2      90.0
# 3      47.0
# 4      76.0
#        ...
# 995    88.0
# 996    62.0
# 997    59.0
# 998    68.0
# 999    77.0
# Name: math score, Length: 1000, dtype: float64
